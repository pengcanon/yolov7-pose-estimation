# %%
# %matplotlib inline 
#nbagg
import matplotlib.pyplot as plt
import numpy as np
import cv2
import json
import math
import scipy
from PIL import Image
import glob
import pickle
from video_utilities import *
import time

# %%
cap = cv2.VideoCapture('fall3.avi')
ret = True
frames =[]
while ret:
    ret, image = cap.read()
    if ret:
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        frames.append(image)

cap.release()
cv2.destroyAllWindows()
frames = frames[:200]
frames[0].shape
# Out:
# (480, 720, 3)

# %%
plt.imshow(frames[2])

# %%
# !python pose-estimate.py --source "football1.mp4" --device cpu
# Out:
# ^C
